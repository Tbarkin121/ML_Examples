# %% [markdown]
# <a href="https://colab.research.google.com/github/Tbarkin121/ML_Examples/blob/main/IntermediateLayers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import math

import keras
from keras.callbacks import TensorBoard
from keras import layers
from keras import models
from keras.layers import Dropout, LeakyReLU, ReLU, ELU
from keras.utils.vis_utils import plot_model
from PIL import Image

import random
np.random.seed(42)

# %%
from keras.utils import to_categorical
from sklearn.utils.multiclass import unique_labels

class Environment:
    def __init__(self, dataset = tf.keras.datasets.fashion_mnist):
      (self.train_images, self.train_labels), (self.test_images, self.test_labels) = dataset.load_data()
      # Hardcoding label names for the fashion_mnist dataset 
      self.class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
                    'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
      self.preprocess_data()

    def Change_Image_Size (self, im, width, height):
        modified_im = []
        for i in range(len(im)):
          tmp = keras.preprocessing.image.array_to_img(im[i])
          tmp = tmp.resize( (width, height), Image.ANTIALIAS )
          modified_im.append(keras.preprocessing.image.img_to_array(tmp))
        return np.asarray(modified_im)

    def preprocess_data(self):
      # Making the data more friendly
      self.train_images = self.train_images.astype('float32')
      
      if (len(self.train_images.shape) == 3):
        self.train_images = self.train_images.reshape((self.train_images.shape[0], self.train_images.shape[1], self.train_images.shape[2], 1))
      else: 
        self.train_images = self.train_images.reshape((self.train_images.shape[0], self.train_images.shape[1], self.train_images.shape[2], self.train_images.shape[3]))

      self.train_images = self.Change_Image_Size(self.train_images, 32, 32)
      self.train_images /= 255
      

      self.test_images = self.test_images.astype('float32')
      
      if (len(self.test_images.shape) == 3):
        self.test_images = self.test_images.reshape((self.test_images.shape[0], self.test_images.shape[1], self.test_images.shape[2], 1))
      else: 
        self.test_images = self.test_images.reshape((self.test_images.shape[0], self.test_images.shape[1], self.test_images.shape[2], self.test_images.shape[3]))

      self.test_images = self.Change_Image_Size(self.test_images, 32, 32)
      self.test_images /= 255
    
      print('Input shape = \n{}\n'.format(self.train_images.shape))
      print('Data type = \n{}\n'.format(type(self.train_images[0][0][0][0])))

      self.train_labels_onehot = to_categorical(self.train_labels)
      self.test_labels_onehot = to_categorical(self.test_labels)

    def show_image(self, im, label):
      # Display some of the images with labels
      num_images = len(im)
      num_cols = 5
      num_rows = np.ceil(num_images/num_cols)
      plt.figure(figsize=(3*num_cols, 3*num_rows))
      for i in range(len(im)):
        plt.subplot(num_rows, num_cols,i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)

        if (im.shape[3] == 1):
          plt.imshow(im[i].reshape(im[i].shape[0], im[i].shape[1]), cmap=plt.cm.binary)
        else:
          plt.imshow(im[i].reshape(im[i].shape[0], im[i].shape[1], im[i].shape[2]), cmap=plt.cm.binary)
        # plt.xlabel(self.class_names[label[i]])
      plt.show()

# %%
# Convolutional Auto Encoder
class ConvoAutoEncoder:
    def __init__(self, Environment, filters = (16, 32), bottle_neck_size = 4 ):
        self.env=Environment
        self.filters = filters
        self.bottle_neck_size = bottle_neck_size

        self.inputShape = self.env.train_images[0].shape
        self.inputs = layers.Input(shape=self.inputShape)

        self.width = self.inputShape[0]
        self.height = self.inputShape[1]
        self.depth = self.inputShape[2]
        
        self.model = self.create_autoencoder()
    
    
    def create_encoder_model(self):
        # loop over the number of layers for encoder
        for (i, f) in enumerate(self.filters):
            if i == 0:
                x = self.inputs
            x = layers.Conv2D(f, (3, 3), padding='same')(x)
            x = layers.LeakyReLU()(x)
            x = layers.MaxPooling2D((2, 2), padding='same')(x)
        #Saving this shape for the decoder 
        self.convshape = x.shape

        x = layers.Flatten()(x)
        x = layers.Dense(self.bottle_neck_size)(x)
        x = layers.LeakyReLU()(x) 
        encoded = x
        model = keras.Model(self.inputs, encoded)
        # model.summary()
        return model
        
    def create_decoder_model(self):
        # Match up the mlp section
        inputs = layers.Input(shape=(self.bottle_neck_size))
        x = inputs
        x = layers.LeakyReLU()(x) 
        x = layers.Dense(self.convshape[1]*self.convshape[2]*self.convshape[3])(x)
        x = layers.Reshape( (self.convshape[1], self.convshape[2], self.convshape[3]) )(x)

        # loop over the number of layers backwords for decoder
        for (i, f) in enumerate(reversed(self.filters)):
            x = layers.Conv2DTranspose(f, (3,3), strides=(2,2), padding='same')(x)
            x = layers.LeakyReLU()(x) 
#             x = layers.Conv2D(f, (3, 3), activation='relu', padding='same')(x)
#             x = layers.UpSampling2D((2, 2))(x)
        
        decoded = layers.Conv2D(self.depth, (3, 3), activation='sigmoid', padding='same')(x)
        model = keras.Model(inputs, decoded)
        # model.summary()
        return model
        
    def create_autoencoder(self):
        self.encoder_model = self.create_encoder_model()
        self.decoder_model = self.create_decoder_model()
        
        encoded = self.encoder_model(self.inputs)
        decoded = self.decoder_model(encoded)

        auto_encoder = keras.Model(self.inputs, decoded)
        
        auto_encoder.compile(
            loss='binary_crossentropy',
            metrics=['mse'],
            optimizer='adam')
        
        return auto_encoder
        
    def run_training(self, n_epochs):
        print('Train autoencoder')
        callbacks = []
        callbacks.append(tf.keras.callbacks.EarlyStopping(monitor='loss', patience=3))
        callbacks.append(TensorBoard(log_dir='/tmp/autoencoder'))
        
        history = self.model.fit(
            x=self.env.train_images,
            y=self.env.train_images,
            validation_data=(self.env.test_images, self.env.test_images),
            batch_size=1000,
            shuffle=True,
            epochs=n_epochs,
            verbose=True,
            callbacks=callbacks)


    def test_encoder(self, n):
      random_samples = random.sample(range(0,len(self.env.test_images)), n)
      test_samples = self.env.test_images[random_samples]
      labels = self.env.test_labels[random_samples]
      decoded_samples = self.model.predict(test_samples)
      self.env.show_image(test_samples, labels)
      self.env.show_image(decoded_samples, labels)

    def IntermediateLayerTest(self):
      self.extractor = keras.Model(inputs=self.encoder_model.inputs, outputs=[layer.output for layer in self.encoder_model.layers])
      feature = conv_ae.extractor(self.env.test_images[0:1])
      return feature

# %%
env = Environment(tf.keras.datasets.mnist)
n_images = 5
env.show_image(env.train_images[0:n_images], env.train_labels[0:n_images])

conv_ae = ConvoAutoEncoder(env, filters = (16, 24, 32), bottle_neck_size = 20 )
conv_ae.run_training(1000)
# conv_ae.model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# Input shape =
# (60000, 32, 32, 1)
#
# Data type =
# <class 'numpy.float32'>
# Train autoencoder
# Epoch 1/1000
# 60/60 [==============================] - 4s 59ms/step - loss: 0.5520 - mse: 0.1636 - val_loss: 0.2753 - val_mse: 0.0640
# Epoch 2/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.2702 - mse: 0.0626 - val_loss: 0.2458 - val_mse: 0.0560
# Epoch 3/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.2357 - mse: 0.0528 - val_loss: 0.2021 - val_mse: 0.0418
# Epoch 4/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1939 - mse: 0.0388 - val_loss: 0.1700 - val_mse: 0.0302
# Epoch 5/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1670 - mse: 0.0291 - val_loss: 0.1538 - val_mse: 0.0243
# Epoch 6/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1519 - mse: 0.0236 - val_loss: 0.1434 - val_mse: 0.0207
# Epoch 7/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1420 - mse: 0.0202 - val_loss: 0.1357 - val_mse: 0.0180
# Epoch 8/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1359 - mse: 0.0180 - val_loss: 0.1306 - val_mse: 0.0163
# Epoch 9/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1313 - mse: 0.0165 - val_loss: 0.1274 - val_mse: 0.0152
# Epoch 10/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1279 - mse: 0.0153 - val_loss: 0.1244 - val_mse: 0.0142
# Epoch 11/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1254 - mse: 0.0144 - val_loss: 0.1229 - val_mse: 0.0137
# Epoch 12/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1235 - mse: 0.0138 - val_loss: 0.1211 - val_mse: 0.0130
# Epoch 13/1000
# 60/60 [==============================] - 3s 45ms/step - loss: 0.1219 - mse: 0.0132 - val_loss: 0.1201 - val_mse: 0.0127
# Epoch 14/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1207 - mse: 0.0128 - val_loss: 0.1182 - val_mse: 0.0120
# Epoch 15/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1192 - mse: 0.0123 - val_loss: 0.1174 - val_mse: 0.0118
# Epoch 16/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1182 - mse: 0.0120 - val_loss: 0.1167 - val_mse: 0.0116
# Epoch 17/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1176 - mse: 0.0118 - val_loss: 0.1158 - val_mse: 0.0112
# Epoch 18/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1169 - mse: 0.0115 - val_loss: 0.1151 - val_mse: 0.0110
# Epoch 19/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1156 - mse: 0.0111 - val_loss: 0.1141 - val_mse: 0.0106
# Epoch 20/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1153 - mse: 0.0110 - val_loss: 0.1135 - val_mse: 0.0105
# Epoch 21/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1147 - mse: 0.0108 - val_loss: 0.1131 - val_mse: 0.0103
# Epoch 22/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1142 - mse: 0.0106 - val_loss: 0.1129 - val_mse: 0.0103
# Epoch 23/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1137 - mse: 0.0105 - val_loss: 0.1121 - val_mse: 0.0100
# Epoch 24/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1130 - mse: 0.0103 - val_loss: 0.1119 - val_mse: 0.0099
# Epoch 25/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1128 - mse: 0.0101 - val_loss: 0.1115 - val_mse: 0.0098
# Epoch 26/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1125 - mse: 0.0101 - val_loss: 0.1111 - val_mse: 0.0097
# Epoch 27/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1118 - mse: 0.0098 - val_loss: 0.1107 - val_mse: 0.0095
# Epoch 28/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1114 - mse: 0.0097 - val_loss: 0.1101 - val_mse: 0.0093
# Epoch 29/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1109 - mse: 0.0096 - val_loss: 0.1101 - val_mse: 0.0094
# Epoch 30/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1110 - mse: 0.0095 - val_loss: 0.1099 - val_mse: 0.0093
# Epoch 31/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1109 - mse: 0.0095 - val_loss: 0.1099 - val_mse: 0.0093
# Epoch 32/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1104 - mse: 0.0093 - val_loss: 0.1090 - val_mse: 0.0090
# Epoch 33/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1100 - mse: 0.0092 - val_loss: 0.1087 - val_mse: 0.0089
# Epoch 34/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1096 - mse: 0.0091 - val_loss: 0.1084 - val_mse: 0.0088
# Epoch 35/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1096 - mse: 0.0091 - val_loss: 0.1085 - val_mse: 0.0088
# Epoch 36/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1094 - mse: 0.0090 - val_loss: 0.1079 - val_mse: 0.0086
# Epoch 37/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1088 - mse: 0.0089 - val_loss: 0.1076 - val_mse: 0.0085
# Epoch 38/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1083 - mse: 0.0087 - val_loss: 0.1076 - val_mse: 0.0085
# Epoch 39/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1084 - mse: 0.0087 - val_loss: 0.1073 - val_mse: 0.0084
# Epoch 40/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1081 - mse: 0.0086 - val_loss: 0.1073 - val_mse: 0.0084
# Epoch 41/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1083 - mse: 0.0086 - val_loss: 0.1070 - val_mse: 0.0083
# Epoch 42/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1077 - mse: 0.0085 - val_loss: 0.1067 - val_mse: 0.0082
# Epoch 43/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1077 - mse: 0.0085 - val_loss: 0.1066 - val_mse: 0.0082
# Epoch 44/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1077 - mse: 0.0084 - val_loss: 0.1066 - val_mse: 0.0082
# Epoch 45/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1074 - mse: 0.0083 - val_loss: 0.1063 - val_mse: 0.0081
# Epoch 46/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1073 - mse: 0.0083 - val_loss: 0.1060 - val_mse: 0.0080
# Epoch 47/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1068 - mse: 0.0082 - val_loss: 0.1061 - val_mse: 0.0080
# Epoch 48/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1070 - mse: 0.0082 - val_loss: 0.1059 - val_mse: 0.0080
# Epoch 49/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1067 - mse: 0.0081 - val_loss: 0.1056 - val_mse: 0.0078
# Epoch 50/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1065 - mse: 0.0081 - val_loss: 0.1062 - val_mse: 0.0080
# Epoch 51/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1064 - mse: 0.0081 - val_loss: 0.1052 - val_mse: 0.0077
# Epoch 52/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1061 - mse: 0.0079 - val_loss: 0.1053 - val_mse: 0.0077
# Epoch 53/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1060 - mse: 0.0079 - val_loss: 0.1051 - val_mse: 0.0077
# Epoch 54/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1060 - mse: 0.0079 - val_loss: 0.1051 - val_mse: 0.0077
# Epoch 55/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1059 - mse: 0.0079 - val_loss: 0.1049 - val_mse: 0.0076
# Epoch 56/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1054 - mse: 0.0078 - val_loss: 0.1046 - val_mse: 0.0075
# Epoch 57/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1054 - mse: 0.0077 - val_loss: 0.1045 - val_mse: 0.0075
# Epoch 58/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1054 - mse: 0.0077 - val_loss: 0.1046 - val_mse: 0.0075
# Epoch 59/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1053 - mse: 0.0077 - val_loss: 0.1046 - val_mse: 0.0075
# Epoch 60/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1052 - mse: 0.0077 - val_loss: 0.1043 - val_mse: 0.0074
# Epoch 61/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1053 - mse: 0.0076 - val_loss: 0.1042 - val_mse: 0.0074
# Epoch 62/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1049 - mse: 0.0075 - val_loss: 0.1042 - val_mse: 0.0074
# Epoch 63/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1048 - mse: 0.0075 - val_loss: 0.1040 - val_mse: 0.0074
# Epoch 64/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1049 - mse: 0.0075 - val_loss: 0.1042 - val_mse: 0.0074
# Epoch 65/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1049 - mse: 0.0075 - val_loss: 0.1038 - val_mse: 0.0073
# Epoch 66/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1048 - mse: 0.0075 - val_loss: 0.1039 - val_mse: 0.0073
# Epoch 67/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1044 - mse: 0.0074 - val_loss: 0.1037 - val_mse: 0.0072
# Epoch 68/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1045 - mse: 0.0074 - val_loss: 0.1037 - val_mse: 0.0072
# Epoch 69/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1043 - mse: 0.0073 - val_loss: 0.1035 - val_mse: 0.0072
# Epoch 70/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1042 - mse: 0.0073 - val_loss: 0.1033 - val_mse: 0.0071
# Epoch 71/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1041 - mse: 0.0073 - val_loss: 0.1035 - val_mse: 0.0072
# Epoch 72/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1040 - mse: 0.0073 - val_loss: 0.1032 - val_mse: 0.0071
# Epoch 73/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1043 - mse: 0.0073 - val_loss: 0.1032 - val_mse: 0.0071
# Epoch 74/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1039 - mse: 0.0072 - val_loss: 0.1032 - val_mse: 0.0071
# Epoch 75/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1038 - mse: 0.0072 - val_loss: 0.1030 - val_mse: 0.0070
# Epoch 76/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1036 - mse: 0.0071 - val_loss: 0.1031 - val_mse: 0.0070
# Epoch 77/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1038 - mse: 0.0072 - val_loss: 0.1030 - val_mse: 0.0070
# Epoch 78/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1036 - mse: 0.0071 - val_loss: 0.1027 - val_mse: 0.0069
# Epoch 79/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1036 - mse: 0.0071 - val_loss: 0.1029 - val_mse: 0.0070
# Epoch 80/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1035 - mse: 0.0071 - val_loss: 0.1026 - val_mse: 0.0069
# Epoch 81/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1034 - mse: 0.0071 - val_loss: 0.1025 - val_mse: 0.0069
# Epoch 82/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1034 - mse: 0.0071 - val_loss: 0.1026 - val_mse: 0.0069
# Epoch 83/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1032 - mse: 0.0070 - val_loss: 0.1028 - val_mse: 0.0070
# Epoch 84/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1034 - mse: 0.0071 - val_loss: 0.1027 - val_mse: 0.0069
# Epoch 85/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1030 - mse: 0.0069 - val_loss: 0.1023 - val_mse: 0.0068
# Epoch 86/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1030 - mse: 0.0069 - val_loss: 0.1022 - val_mse: 0.0068
# Epoch 87/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1030 - mse: 0.0069 - val_loss: 0.1025 - val_mse: 0.0069
# Epoch 88/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1029 - mse: 0.0069 - val_loss: 0.1023 - val_mse: 0.0068
# Epoch 89/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1028 - mse: 0.0069 - val_loss: 0.1022 - val_mse: 0.0067
# Epoch 90/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1027 - mse: 0.0068 - val_loss: 0.1022 - val_mse: 0.0067
# Epoch 91/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1026 - mse: 0.0068 - val_loss: 0.1022 - val_mse: 0.0068
# Epoch 92/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1030 - mse: 0.0069 - val_loss: 0.1022 - val_mse: 0.0068
# Epoch 93/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1026 - mse: 0.0068 - val_loss: 0.1019 - val_mse: 0.0067
# Epoch 94/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1026 - mse: 0.0068 - val_loss: 0.1020 - val_mse: 0.0067
# Epoch 95/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1023 - mse: 0.0068 - val_loss: 0.1018 - val_mse: 0.0066
# Epoch 96/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1025 - mse: 0.0068 - val_loss: 0.1018 - val_mse: 0.0066
# Epoch 97/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1026 - mse: 0.0068 - val_loss: 0.1021 - val_mse: 0.0067
# Epoch 98/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1024 - mse: 0.0068 - val_loss: 0.1016 - val_mse: 0.0066
# Epoch 99/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1023 - mse: 0.0067 - val_loss: 0.1015 - val_mse: 0.0066
# Epoch 100/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1023 - mse: 0.0067 - val_loss: 0.1016 - val_mse: 0.0066
# Epoch 101/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1021 - mse: 0.0067 - val_loss: 0.1017 - val_mse: 0.0066
# Epoch 102/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1021 - mse: 0.0067 - val_loss: 0.1014 - val_mse: 0.0065
# Epoch 103/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1020 - mse: 0.0066 - val_loss: 0.1016 - val_mse: 0.0066
# Epoch 104/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1019 - mse: 0.0066 - val_loss: 0.1014 - val_mse: 0.0065
# Epoch 105/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1020 - mse: 0.0066 - val_loss: 0.1014 - val_mse: 0.0065
# Epoch 106/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1020 - mse: 0.0066 - val_loss: 0.1015 - val_mse: 0.0066
# Epoch 107/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1018 - mse: 0.0066 - val_loss: 0.1013 - val_mse: 0.0065
# Epoch 108/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1021 - mse: 0.0066 - val_loss: 0.1013 - val_mse: 0.0065
# Epoch 109/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1016 - mse: 0.0065 - val_loss: 0.1013 - val_mse: 0.0065
# Epoch 110/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1017 - mse: 0.0066 - val_loss: 0.1012 - val_mse: 0.0064
# Epoch 111/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1017 - mse: 0.0065 - val_loss: 0.1011 - val_mse: 0.0064
# Epoch 112/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1014 - mse: 0.0065 - val_loss: 0.1011 - val_mse: 0.0064
# Epoch 113/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1017 - mse: 0.0065 - val_loss: 0.1011 - val_mse: 0.0064
# Epoch 114/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1016 - mse: 0.0065 - val_loss: 0.1012 - val_mse: 0.0064
# Epoch 115/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1015 - mse: 0.0065 - val_loss: 0.1009 - val_mse: 0.0064
# Epoch 116/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1016 - mse: 0.0065 - val_loss: 0.1012 - val_mse: 0.0065
# Epoch 117/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1014 - mse: 0.0064 - val_loss: 0.1010 - val_mse: 0.0064
# Epoch 118/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1013 - mse: 0.0064 - val_loss: 0.1009 - val_mse: 0.0064
# Epoch 119/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1016 - mse: 0.0065 - val_loss: 0.1007 - val_mse: 0.0063
# Epoch 120/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1014 - mse: 0.0064 - val_loss: 0.1011 - val_mse: 0.0064
# Epoch 121/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1014 - mse: 0.0064 - val_loss: 0.1007 - val_mse: 0.0063
# Epoch 122/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1014 - mse: 0.0064 - val_loss: 0.1007 - val_mse: 0.0063
# Epoch 123/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1011 - mse: 0.0063 - val_loss: 0.1007 - val_mse: 0.0063
# Epoch 124/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1013 - mse: 0.0064 - val_loss: 0.1006 - val_mse: 0.0063
# Epoch 125/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1012 - mse: 0.0063 - val_loss: 0.1005 - val_mse: 0.0062
# Epoch 126/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1011 - mse: 0.0063 - val_loss: 0.1007 - val_mse: 0.0063
# Epoch 127/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1008 - mse: 0.0063 - val_loss: 0.1006 - val_mse: 0.0063
# Epoch 128/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1012 - mse: 0.0063 - val_loss: 0.1006 - val_mse: 0.0063
# Epoch 129/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1012 - mse: 0.0063 - val_loss: 0.1008 - val_mse: 0.0063
# Epoch 130/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1009 - mse: 0.0063 - val_loss: 0.1004 - val_mse: 0.0062
# Epoch 131/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1010 - mse: 0.0063 - val_loss: 0.1010 - val_mse: 0.0064
# Epoch 132/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1011 - mse: 0.0063 - val_loss: 0.1006 - val_mse: 0.0063
# Epoch 133/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1009 - mse: 0.0063 - val_loss: 0.1004 - val_mse: 0.0062
# Epoch 134/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1008 - mse: 0.0063 - val_loss: 0.1003 - val_mse: 0.0062
# Epoch 135/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1009 - mse: 0.0063 - val_loss: 0.1004 - val_mse: 0.0062
# Epoch 136/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1009 - mse: 0.0063 - val_loss: 0.1003 - val_mse: 0.0062
# Epoch 137/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1007 - mse: 0.0062 - val_loss: 0.1003 - val_mse: 0.0062
# Epoch 138/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1008 - mse: 0.0062 - val_loss: 0.1002 - val_mse: 0.0061
# Epoch 139/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1008 - mse: 0.0062 - val_loss: 0.1001 - val_mse: 0.0061
# Epoch 140/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1007 - mse: 0.0062 - val_loss: 0.1002 - val_mse: 0.0061
# Epoch 141/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1006 - mse: 0.0062 - val_loss: 0.1002 - val_mse: 0.0061
# Epoch 142/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1005 - mse: 0.0061 - val_loss: 0.1005 - val_mse: 0.0063
# Epoch 143/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1006 - mse: 0.0062 - val_loss: 0.1001 - val_mse: 0.0061
# Epoch 144/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1005 - mse: 0.0062 - val_loss: 0.1001 - val_mse: 0.0061
# Epoch 145/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1006 - mse: 0.0062 - val_loss: 0.1000 - val_mse: 0.0061
# Epoch 146/1000
# 60/60 [==============================] - 3s 46ms/step - loss: 0.1005 - mse: 0.0061 - val_loss: 0.1000 - val_mse: 0.0061
# Epoch 147/1000
# 60/60 [==============================] - 3s 47ms/step - loss: 0.1005 - mse: 0.0062 - val_loss: 0.0999 - val_mse: 0.0060

# %%
features = conv_ae.IntermediateLayerTest()

for i in range(len(features)):
  print('Layer {}'.format(i))
  print(conv_ae.encoder_model.layers[i])
  print(features[i].shape)
# Out:
# Layer 0
# <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x7f87100eca10>
# (1, 32, 32, 1)
# Layer 1
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f86c7eb5fd0>
# (1, 32, 32, 16)
# Layer 2
# <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f86cc306050>
# (1, 32, 32, 16)
# Layer 3
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f87100ec810>
# (1, 16, 16, 16)
# Layer 4
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f871010b550>
# (1, 16, 16, 24)
# Layer 5
# <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f8718757650>
# (1, 16, 16, 24)
# Layer 6
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f87187ff4d0>
# (1, 8, 8, 24)
# Layer 7
# <tensorflow.python.keras.layers.convolutional.Conv2D object at 0x7f86c7d18210>
# (1, 8, 8, 32)
# Layer 8
# <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f87186df550>
# (1, 8, 8, 32)
# Layer 9
# <tensorflow.python.keras.layers.pooling.MaxPooling2D object at 0x7f8718776190>
# (1, 4, 4, 32)
# Layer 10
# <tensorflow.python.keras.layers.core.Flatten object at 0x7f8718761850>
# (1, 512)
# Layer 11
# <tensorflow.python.keras.layers.core.Dense object at 0x7f86c7d2ca50>
# (1, 20)
# Layer 12
# <tensorflow.python.keras.layers.advanced_activations.LeakyReLU object at 0x7f86c7d2ca10>
# (1, 20)

# %%
layer_to_observe = 2
num_cols = 5
num_rows = 4
plt.figure(figsize=(3*num_cols, 3*num_rows))
for i in range(features[1].shape[3]):
  im = features[layer_to_observe][0][:,:,i]
  # plt.imshow(im, cmap=plt.cm.binary)
  # print(im.shape)
  plt.subplot(num_rows, num_cols,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(im, cmap=plt.cm.binary)
plt.show()

# %%
layer_to_observe = 5
num_cols = 5
num_rows = np.ceil(features[layer_to_observe].shape[3]/num_cols)
plt.figure(figsize=(3*num_cols, 3*num_rows))
for i in range(features[layer_to_observe].shape[3]):
  im = features[layer_to_observe][0][:,:,i]
  # plt.imshow(im, cmap=plt.cm.binary)
  # print(im.shape)
  plt.subplot(num_rows, num_cols,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(im, cmap=plt.cm.binary)
plt.show()

# %%
layer_to_observe = 
num_cols = 5
num_rows = np.ceil(features[layer_to_observe].shape[3]/num_cols)
plt.figure(figsize=(3*num_cols, 3*num_rows))
for i in range(features[layer_to_observe].shape[3]):
  im = features[layer_to_observe][0][:,:,i]
  # plt.imshow(im, cmap=plt.cm.binary)
  # print(im.shape)
  plt.subplot(num_rows, num_cols,i+1)
  plt.xticks([])
  plt.yticks([])
  plt.grid(False)
  plt.imshow(im, cmap=plt.cm.binary)
plt.show()
